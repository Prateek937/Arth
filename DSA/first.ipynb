# %%
#algo
# steps

# %%
import traceback

def learnAI():
    learnPy()
    print("Do Step 1")
    
def learnPy():
    learnComputer()
    print("Python for step 1.")

def learnComputer():
    print("Learning computer.")
    traceback.print_stack()

# %%
learnAI()
# Out:
# Learning computer.
# Python for step 1.
# Do Step 1
#   File "/usr/lib64/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib64/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/prateek/.local/lib/python3.9/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.9/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/prateek/.local/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/prateek/.local/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 596, in run_forever
#     self._run_once()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 1890, in _run_once
# ...

# %%
def prateek():
    print("a")
    print("b")
    for i in range(5):
        print("c")

# %%
prateek()
# Out:
# a
# b
# c
# c
# c
# c
# c

# %%
# %timeit prateek()
# Out:
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# ...

# %%
! pip install line_profiler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %load_ext line_profiler

# %%
# %lprun -f prateek prateek()
# Out:
# a
# b
# c
# c
# c
# c
# c
# Timer unit: 1e-06 s
#
# Total time: 0.000694 s
# File: <ipython-input-4-8eed7a0a2630>
# Function: prateek at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      1                                           def prateek():
#      2         1        168.0    168.0     24.2      print("a")
#      3         1         57.0     57.0      8.2      print("b")
#      4         6         11.0      1.8      1.6      for i in range(5):
#      5         5        458.0     91.6     66.0          print("c")

# %%
! pip install memory_profiler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %load_ext memory_profiler

# %%
# %memit prateek()
# Out:
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# a
# b
# c
# c
# c
# c
# c
# peak memory: 52.41 MiB, increment: 0.13 MiB
